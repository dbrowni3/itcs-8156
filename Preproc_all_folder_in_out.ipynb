# %%
'''
This code contains all the preprocessing functions to load in and process data.

'''

#Import Libraries
import os # operating system module
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # visualization and plotting
import seaborn as sns # statistical plotting
from datetime import datetime # Convert Datetime 
from sklearn.model_selection import TimeSeriesSplit, train_test_split # for linear model
from sklearn.preprocessing import StandardScaler #for scaling data
from sklearn.preprocessing import MinMaxScaler #for scaling data

from torch.utils.data import TensorDataset, DataLoader
import torch




def get_data(f,st,sn):
    
    full_fp = (f + "\\" + st + "\\" + sn + ".us.txt")
    df = pd.read_csv(full_fp)
    
    return df

def del_OI(df_sorted):            

    df_dropped = df_sorted.drop(labels=["OpenInt"], axis=1)
    
    return df_dropped

def std_vol(df_dropped, stdzr):
    
    scaled_features = df_dropped.copy()
    col_names = df_dropped.columns.values
    col_names = np.delete(col_names,np.argwhere(col_names=='Date'))

    # col_names = np.delete(col_names,np.argwhere(col_names=='Close'))
    # col_names = ['Volume']
    features = scaled_features[col_names]
    if (stdzr == 'standard'):
        scaler = StandardScaler().fit(features.values)
    elif (stdzr == 'minmax'):
        scaler = MinMaxScaler().fit(features.values)

    features = scaler.transform(features.values)
    scaled_features[col_names] = features
    
    
    df_scaled = scaled_features
    
    return df_scaled

def get_daily_deltas(df_scaled):

    df_scaled["High-Low"] = df_scaled["High"] - df_scaled["Low"]
    df_scaled["Close-Open"] = df_scaled["Close"] - df_scaled["Open"]

    return df_scaled

def nearendquarter(month,day):

    if month in [3, 6, 9, 12]:
        if month in [3, 12]:
            if day in [31, 30, 29, 28, 27, 26, 25]:
                return 1
            else:
                return 0
        else:
            if day in [30, 29, 28, 27, 26, 25, 24]:
                return 1
            else: 
                return 0
    else:
        return 0

def convertdatetime(s):
    
    date = pd.to_datetime(s)

    return date

def converttoday(dt):

    dt =  dt.weekday()

    return dt

def near_end_quart(df_added):

    splitted = df_added['Date'].str.split('-', expand=True)
 
    df_added['Day_date'] = splitted[2].astype('int')
    df_added['Month'] = splitted[1].astype('int')
    df_added['Year'] = splitted[0].astype('int')

    
    df_added['near_end_quarter'] = df_added.apply(lambda x: \
        nearendquarter(x['Month'], x['Day_date']), axis=1)
    
    
    #convert Date to datetime in order to day the day of the week
    df_added['Date'] = df_added['Date'].apply(convertdatetime)
    df_added['Day'] = df_added['Date'].apply(converttoday)

    #reindex by the date so it can be split into time series data later
    df_added.set_index('Date',inplace=True)
    df_added.sort_index(inplace=True)

    return df_added

def split_data(df_end_quart):

    X = df_end_quart.drop(labels=["Close"], axis=1)
    T = df_end_quart["Close"]

    tss = TimeSeriesSplit(n_splits = 2)

    for train_indx, test_indx in tss.split(X):
    
        X_train, X_test = X.iloc[train_indx, :], X.iloc[test_indx,:]
        T_train, T_test = T.iloc[train_indx], T.iloc[test_indx] 

    return X_train, X_test, T_train, T_test

def  market_prepro(f,st,sn, verbose=False, splitdata=True, stdzr='minmax'):
    # df = get_data(f,st,sn) #get the dataset imported 
    #removed the above line - RD
    df_dropped = del_OI(f)
    df_scaled = std_vol(df_dropped,stdzr)
    df_added = get_daily_deltas(df_scaled)
    df_end_quart = near_end_quart(df_added)
    X_train, X_test, T_train, T_test = split_data(df_end_quart)


    if verbose == True:
        print(df_end_quart.head())
        print(df_end_quart.info())
        print(df_end_quart.describe())
        print("The start date of the training data is ", (X_train[:1]))
        print("The last date of the training data is ", (X_train[-1:]))
        print("The start date of the training data is ", (X_test[:1]))
        print("The last date of the training data is ", (X_test[-1:]))

        # sns.heatmap(df_end_quart.corr(),annot=True, square=True, cmap='terrain', linewidths=0.1)
        # sns.pairplot(df_end_quart)
        plt.show()

    if (splitdata == True):
        X_train, X_test, T_train, T_test = split_data(df_end_quart)
        return X_train, X_test, T_train, T_test
    else:
        X = df_end_quart.drop(labels=["Close"], axis=1)
        T = df_end_quart["Close"]
        return X, T


def structure_timeseries_features(df,offset_back, offset_for,exclude):
    '''
    This takes a dataframe and creates new columns that contain the data from
    previous days so that time series forecasting can occur.

    INPUTS:
        df - dataframe: input data

        offset_back - int: the number of days to go back. This creates this many
                        new columns

        offset_for - int: the number of days to go forwards. This creates this many
                        new columns

        exclude - list str: list of columns to exclude from the time series 
                            expansion

    OUTPUTS:
        df_out - dataframe: dataframe with new columns
    '''

    df_out = pd.DataFrame() 

    for cc in df.columns.values:
        if (cc not in exclude):
            for ii in range(offset_back):
                col_name = (cc+"_m"+str(ii+1))

                df_out[col_name] = df[cc].shift(ii+1)


    df_out = df_out.iloc[offset_back:-offset_for,:]

    return df_out

def structure_timeseries_targets(df,offset_back, offset_for,filename):
    '''
    companion function to remove the first few days of targets to make sure
    the sizes match between features and targets. Also offset the data for
    multi day targets

    INPUTS:
        df - dataframe: input data targets.

        offset_back - int: the number of days to go back. This creates this many
                        new columns
                        
        offset_for - int: the number of days to go forwards. This creates this many
                        new columns
        filename = complete directory for the dataset selected - RD

    OUTPUTS:
        df_out - dataframe: dataframe with rows removed

    '''
#     # df_out = df.iloc[offset:]

#     df_out = pd.DataFrame() 

#     # for cc in df.columns.values:
#     for ii in range(offset_for):
#         col_name = (df.name+"_p"+str(ii))

#         df_out[col_name] = df.shift(-(ii))


#     df_out = df_out.iloc[offset_back:-offset_for,:]

#     return df_out
# Changed from previous one - RD

    file_name = os.path.basename(filename)
    df = pd.read_csv(filename)
    df_out = pd.DataFrame()

    for ii in range(offset_for):
        cols = df.shift(-(ii)).columns
        for j in range(len(cols)):
            col_name = (file_name+"_p"+str(ii))
            df_out[col_name + '_' + str(j)] = df.shift(-(ii))[cols[j]]
    df_out = df_out.iloc[offset_back:-offset_for,:]
    return df_out

def lstm_timeseries_feat_and_targ(df_feat, df_targ, offset_back, offset_for, exclude):
    '''
    This takes a dataframe and creates new columns that contain the data from
    previous days so that time series forecasting can occur.

    INPUTS:
        df - dataframe: input data

        offset_back - int: the number of days to go back. This include the current day
                            current day + (offset_back - 1 ) = offset_back

        offset_for - int: the number of days to go forwards. This creates this many
                        new columns

        exclude - list str: list of columns to exclude from the time series 
                            expansion

    OUTPUTS:
        dataloader - dataframe: dataframe with new columns
    '''
    # if (exclude is not None and isinstance(df_feat, pd.DataFrame)):
    #     df_feat = df_feat.drop(exclude, axis=1)
    #changed -Rd
    if exclude is not None:
        exclude = [col for col in exclude if col in df_feat.columns]
        df_feat = df_feat.drop(exclude, axis=1)
    # the offset number includes the current day so for an offset_back = 2
    # you only need the current day and one day back. So I am going to switch it to
    # offset_back = offset_back - 1

    # get the number of samples that will be created. trim off the ends that
    # can't be used
    num_samps = len(df_feat) - (offset_back - 1) - offset_for
    indx_end = len(df_feat)

    # get the number of features
    if isinstance(df_feat, pd.Series):
        num_feats = 1
    else:
        num_feats = len(df_feat.columns)

    # init the feature and target arrays
    features = np.zeros((num_samps, num_feats, offset_back))
    targets = np.zeros((num_samps, offset_for+1))

    for ii, dd in enumerate(range(offset_back-1, indx_end-offset_for)):
  
        if isinstance(df_feat,pd.Series):
             feat_temp = df_feat.iloc[dd-offset_back+1:dd+1].to_numpy().T
        else:
             feat_temp = df_feat.iloc[dd-offset_back+1:dd+1,:].to_numpy().T
  
        if (offset_for == 0):
            targ_temp = df_targ.iloc[dd]
        else:
            targ_temp = df_targ.iloc[dd:dd+offset_for+1].to_numpy()
        if len(targ_temp) != offset_for+1:
            targ_temp = np.concatenate([targ_temp, np.zeros((offset_for+1-len(targ_temp),))])
  
        features[ii, :, :] = feat_temp
        targets[ii, :] = targ_temp
            
    # transform numpy to torch
    features = torch.from_numpy(features)    
    targets = torch.from_numpy(targets)    
  
    # add the data into a dataloader
    dataset = TensorDataset(features, targets)
    dataloader = DataLoader(dataset, num_workers=2)

    return dataloader, dataset


# def test():
#     # st = "Stocks"
#     st = "ETFs"

#     #Input stock name
#     sn = "aadr" 
#     f ="C:\\Users\\rjdeo\\OneDrive - University of North Carolina at Charlotte\\Spring 2023\\ICTS 6156\\Project\\Dataset\\Data_Stockand ETP\\Data\\stocks"
#     X_train, X_test, T_train, T_test = market_prepro(f,st,sn,False,splitdata=True)
#     # X,T = market_prepro(f,st,sn,False,splitdata=False, stdzr='minmax')

#     # dl, ds = lstm_timeseries_feat_and_targ(X, T, 3, 1,[ 'Year', 'Month' ,'Day_date', 'Day'])

#     # dl_train, ds_train = lstm_timeseries_feat_and_targ(X_train, T_train, 6, 1, [ 'Year', 'Month' ,'Day_date', 'Day'])
#     dl_test, ds_test = lstm_timeseries_feat_and_targ(X_test, T_test, 2, 2, [ 'Year', 'Month' ,'Day_date', 'Day'])

#     print(ds_test[-1])
#     # print(ds_train[-6])




    
#     # print(X_test.head(10))
#     # print(T_test.head(10))
#     print(X_test.tail(10))
#     print(T_test.tail(10))
#     # print(np.where(T == np.min(T)))

#     # print(ds.shape)



# if __name__ == "__main__":
#     test()

# %%
import os # operating system module
# Setting up the Dataset Directory
f = "C:\\Users\\rjdeo\\OneDrive - University of North Carolina at Charlotte\\Spring 2023\\ICTS 6156\\Project\\Dataset\\Data_Stockand ETP\\Data"
os.chdir(f)
print(f"The current path for your notebook is:\n {os.getcwd()} \n")
print(f"Your notebook is currently in the following directory:\n {os.path.basename(os.getcwd())}")
# Out:
# The current path for your notebook is:
#  C:\Users\rjdeo\OneDrive - University of North Carolina at Charlotte\Spring 2023\ICTS 6156\Project\Dataset\Data_Stockand ETP\Data
#
# Your notebook is currently in the following directory:
#  Data

# %%
import os
import glob
import pandas as pd
import pickle

def preprocess_all(input_path, output_path, st, verbose, splitdata, stdzr, offset_back, offset_for, exclude, df_feat, df_targ):
    all_files = glob.glob(os.path.join(input_path, '*.us.txt'))
    num_files = len(all_files)
    print(f"Selected input folder: {input_path}, \033[1m\033[43mNumber of files to be processed: {num_files}\033[0m")
    output_dir = os.path.join(output_path, f"offset_{offset_back}_{offset_for}")
    if not os.path.exists(output_dir):
        os.mkdir(output_dir)
    print(f"Saving preprocessed data to {output_dir}")
    for filename in all_files:
        sn = os.path.basename(filename).split(".")[0]
        print(f"Selected dataset: {filename}")
        print(f"\033[1m\033[43mSTOCK NAME: {sn}\033[0m")
        df = pd.read_csv(filename)
        if splitdata:
            X_train, X_test, T_train, T_test = market_prepro(df, st, sn, verbose, splitdata, stdzr)
        else:
            X, T = market_prepro(df, st, sn, verbose, splitdata, stdzr)

        df_outf = structure_timeseries_features(df, offset_back, offset_for, exclude)
        df_Outt = structure_timeseries_targets(df,offset_back, offset_for,filename)
        dl_train, ds_train = lstm_timeseries_feat_and_targ(X_train, T_train, offset_back, offset_for, exclude)
        dl_test, ds_test = lstm_timeseries_feat_and_targ(X_test, T_test, offset_back, offset_for, exclude)
        data_dict = {"dataset": dl_train, "dataloader": dl_test}
        output_file = os.path.join(output_dir, f"{sn}_{offset_back}_{offset_for}_preprocessed.pkl")
        if os.path.exists(output_file):
            overwrite = input(f"File {output_file} already exists. Do you want to overwrite it? (y/n)")
            if overwrite.lower() != "y":
                print("Not saving file.")
                continue
        with open(output_file, 'wb') as f:
            pickle.dump(data_dict, f)
            print(f"Preprocessed data saved to {output_file}")     


def main():
    st = input("Enter stock type (Stocks/ETFs): ")

    if st == "Stocks":
        input_path = "C:\\Users\\rjdeo\\OneDrive - University of North Carolina at Charlotte\\Spring 2023\\ICTS 6156\\Project\\Dataset\\Data_Stockand ETP\\Data\\Stocks"
    else:
        input_path = "C:\\Users\\rjdeo\\OneDrive - University of North Carolina at Charlotte\\Spring 2023\\ICTS 6156\\Project\\Dataset\\Data_Stockand ETP\\Data\\Etfs_1"
    if st == "Stocks":
        output_path = "C:\\Users\\rjdeo\\OneDrive - University of North Carolina at Charlotte\\Spring 2023\\ICTS 6156\\Project\\Dataset\\Output\\preprocessed_stock\\Stocks"
        # output_path = f"C:\\Users\\rjdeo\\OneDrive - University of North Carolina at Charlotte\\Spring 2023\\ICTS 6156\\Project\\Dataset\\Output\\preprocessed_stock\\{st}\\offset_back_{offset_back}_offset_for_{offset_for}"
        # print(output_path)
    else:
        output_path = "C:\\Users\\rjdeo\\OneDrive - University of North Carolina at Charlotte\\Spring 2023\\ICTS 6156\\Project\\Dataset\\Output\\preprocessed_stock\\ETFs"
    #     print(output_path)    
    # output_path ="C:\\Users\\rjdeo\\OneDrive - University of North Carolina at Charlotte\\Spring 2023\\ICTS 6156\\Project\\Dataset\\Output\\preprocessed_stock"
    # output_path = input("Enter the path and filename to save the output pickle file (e.g. /path/to/output.pkl): ")
    # print(output_path)
    verbose = input("Would you like to see the output of the preprocess_all function (y/n)? ")
    if verbose == "y":
        verbose = True
    else:
        verbose = False
    
    splitdata = input("Would you like to split the data into training and testing sets (y/n)? ")
    if splitdata == "y":
        splitdata = True
    else:
        splitdata = False
    
    stdzr = input("Enter the type of scaler to use (minmax/standard): ")
    
    offset_back = int(input("Enter the number of days to go back: "))
    offset_for = int(input("Enter the number of days to go forwards: "))    
    exclude = input("Enter a comma-separated list of columns to exclude(ex: ([ 'Year', 'Month' ,'Day_date', 'Day']): ")
    if exclude:
        exclude = exclude.split(",")
    
    preprocess_all(input_path, output_path, st, verbose, splitdata, stdzr, offset_back=offset_back, offset_for=offset_for, exclude=exclude, df_feat=None, df_targ=None)

if __name__ == '__main__':
    main()
# Out:
# Enter stock type (Stocks/ETFs):  ETFs
# Would you like to see the output of the preprocess_all function (y/n)?  y
# Would you like to split the data into training and testing sets (y/n)?  y
# Enter the type of scaler to use (minmax/standard):  minmax
# Enter the number of days to go back:  5
# Enter the number of days to go forwards:  6
# Enter a comma-separated list of columns to exclude(ex: ([ 'Year', 'Month' ,'Day_date', 'Day']):  [ 'Year', 'Month' ,'Day_date', 'Day']
# Selected input folder: C:\Users\rjdeo\OneDrive - University of North Carolina at Charlotte\Spring 2023\ICTS 6156\Project\Dataset\Data_Stockand ETP\Data\Etfs_1, Number of files to be processed: 9
# Saving preprocessed data to C:\Users\rjdeo\OneDrive - University of North Carolina at Charlotte\Spring 2023\ICTS 6156\Project\Dataset\Output\preprocessed_stock\ETFs\offset_5_6
# Selected dataset: C:\Users\rjdeo\OneDrive - University of North Carolina at Charlotte\Spring 2023\ICTS 6156\Project\Dataset\Data_Stockand ETP\Data\Etfs_1\aadr.us.txt
# STOCK NAME: aadr
#                 Open      High       Low     Close    Volume  High-Low  \
# Date
# 2010-07-21  0.011446  0.011129  0.002335  0.000000  0.408142  0.008794
# 2010-07-22  0.020413  0.020072  0.014631  0.015688  0.169865  0.005442
# 2010-07-23  0.023729  0.023380  0.013212  0.016268  0.083807  0.010168
# 2010-07-26  0.019836  0.019497  0.017202  0.018820  0.183169  0.002295
# 2010-07-27  0.015598  0.016420  0.016670  0.016558  0.079652 -0.000250
#
#             Close-Open  Day_date  Month  Year  near_end_quarter  Day
# Date
# 2010-07-21   -0.011446        21      7  2010                 0    2
# 2010-07-22   -0.004724        22      7  2010                 0    3
# 2010-07-23   -0.007460        23      7  2010                 0    4
# 2010-07-26   -0.001016        26      7  2010                 0    0
# 2010-07-27    0.000960        27      7  2010                 0    1
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1565 entries, 2010-07-21 to 2017-11-10
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Open              1565 non-null   float64
#  1   High              1565 non-null   float64
#  2   Low               1565 non-null   float64
#  3   Close             1565 non-null   float64
#  4   Volume            1565 non-null   float64
#  5   High-Low          1565 non-null   float64
#  6   Close-Open        1565 non-null   float64
#  7   Day_date          1565 non-null   int32
#  8   Month             1565 non-null   int32
#  9   Year              1565 non-null   int32
#  10  near_end_quarter  1565 non-null   int64
#  11  Day               1565 non-null   int64
# dtypes: float64(7), int32(3), int64(2)
# memory usage: 140.6 KB
# None
#               Open         High          Low        Close       Volume  \
# count  1565.000000  1565.000000  1565.000000  1565.000000  1565.000000
# mean      0.348246     0.350581     0.354338     0.349191     0.060780
# std       0.200604     0.201373     0.203300     0.201073     0.113505
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.169905     0.173118     0.175923     0.171558     0.004965
# 50%       0.362588     0.363059     0.368132     0.363009     0.014670
# 75%       0.433082     0.436447     0.440990     0.431852     0.056446
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#           High-Low   Close-Open     Day_date        Month         Year  \
# count  1565.000000  1565.000000  1565.000000  1565.000000  1565.000000
# mean     -0.003757     0.000946    15.834505     6.677316  2013.872843
# std       0.009827     0.008695     8.804721     3.441142     2.185996
# min      -0.023190    -0.075650     1.000000     1.000000  2010.000000
# 25%      -0.009409    -0.001600     8.000000     4.000000  2012.000000
# 50%      -0.005170     0.001355    16.000000     7.000000  2014.000000
# 75%      -0.000425     0.003898    23.000000    10.000000  2016.000000
# max       0.115481     0.050990    31.000000    12.000000  2017.000000
#
#        near_end_quarter          Day
# count       1565.000000  1565.000000
# mean           0.077955     2.017891
# std            0.268187     1.393146
# min            0.000000     0.000000
# 25%            0.000000     1.000000
# 50%            0.000000     2.000000
# 75%            0.000000     3.000000
# max            1.000000     4.000000
# The start date of the training data is                  Open      High       Low    Volume  High-Low  Close-Open  \
# Date
# 2010-07-21  0.011446  0.011129  0.002335  0.408142  0.008794   -0.011446
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2010-07-21        21      7  2010                 0    2
# The last date of the training data is                  Open      High       Low    Volume  High-Low  Close-Open  \
# Date
# 2015-09-14  0.346039  0.344855  0.356782  0.000933 -0.011926    0.001717
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2015-09-14        14      9  2015                 0    0
# The start date of the training data is                  Open      High       Low    Volume  High-Low  Close-Open  \
# Date
# 2015-09-15  0.346039  0.344855  0.356782  0.000933 -0.011926    0.001717
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2015-09-15        15      9  2015                 0    1
# The last date of the training data is                  Open      High       Low    Volume  High-Low  Close-Open  \
# Date
# 2017-11-10  0.952139  0.949387  0.961307  0.275408  -0.01192   -0.011007
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2017-11-10        10     11  2017                 0    4
# Preprocessed data saved to C:\Users\rjdeo\OneDrive - University of North Carolina at Charlotte\Spring 2023\ICTS 6156\Project\Dataset\Output\preprocessed_stock\ETFs\offset_5_6\aadr_5_6_preprocessed.pkl
# Selected dataset: C:\Users\rjdeo\OneDrive - University of North Carolina at Charlotte\Spring 2023\ICTS 6156\Project\Dataset\Data_Stockand ETP\Data\Etfs_1\aaxj.us.txt
# STOCK NAME: aaxj
#                 Open      High       Low     Close    Volume  High-Low  \
# Date
# 2008-08-15  0.400304  0.390132  0.445071  0.411559  0.000000 -0.054939
# 2008-08-18  0.394194  0.383938  0.427206  0.392783  0.002708 -0.043268
# 2008-08-19  0.369886  0.359296  0.416745  0.381788  0.000000 -0.057449
# 2008-08-20  0.381935  0.371511  0.427506  0.393099  0.000416 -0.055995
# 2008-08-22  0.385332  0.374954  0.429715  0.396423  0.000372 -0.054761
#
#             Close-Open  Day_date  Month  Year  near_end_quarter  Day
# Date
# 2008-08-15    0.011256        15      8  2008                 0    4
# 2008-08-18   -0.001411        18      8  2008                 0    0
# 2008-08-19    0.011902        19      8  2008                 0    1
# 2008-08-20    0.011163        20      8  2008                 0    2
# 2008-08-22    0.011091        22      8  2008                 0    4
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2325 entries, 2008-08-15 to 2017-11-10
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Open              2325 non-null   float64
#  1   High              2325 non-null   float64
#  2   Low               2325 non-null   float64
#  3   Close             2325 non-null   float64
#  4   Volume            2325 non-null   float64
#  5   High-Low          2325 non-null   float64
#  6   Close-Open        2325 non-null   float64
#  7   Day_date          2325 non-null   int32
#  8   Month             2325 non-null   int32
#  9   Year              2325 non-null   int32
#  10  near_end_quarter  2325 non-null   int64
#  11  Day               2325 non-null   int64
# dtypes: float64(7), int32(3), int64(2)
# memory usage: 208.9 KB
# None
#               Open         High          Low        Close       Volume  \
# count  2325.000000  2325.000000  2325.000000  2325.000000  2325.000000
# mean      0.550056     0.547245     0.578464     0.558003     0.068956
# std       0.170976     0.171684     0.161913     0.167876     0.074162
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.478975     0.475714     0.510258     0.488968     0.026623
# 50%       0.567856     0.564971     0.597657     0.576239     0.048467
# 75%       0.639336     0.636145     0.661625     0.644361     0.084049
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#           High-Low   Close-Open     Day_date        Month         Year  \
# count  2325.000000  2325.000000  2325.000000  2325.000000  2325.000000
# mean     -0.031219     0.007947    15.716559     6.629677  2012.741075
# std       0.016807     0.009282     8.755382     3.415954     2.685792
# min      -0.076844    -0.066973     1.000000     1.000000  2008.000000
# 25%      -0.037102     0.002940     8.000000     4.000000  2010.000000
# 50%      -0.031616     0.007499    16.000000     7.000000  2013.000000
# 75%      -0.025436     0.012245    23.000000    10.000000  2015.000000
# max       0.515860     0.083110    31.000000    12.000000  2017.000000
#
#        near_end_quarter          Day
# count       2325.000000  2325.000000
# mean           0.075269     2.019785
# std            0.263881     1.400008
# min            0.000000     0.000000
# 25%            0.000000     1.000000
# 50%            0.000000     2.000000
# 75%            0.000000     3.000000
# max            1.000000     4.000000
# The start date of the training data is                  Open      High       Low  Volume  High-Low  Close-Open  \
# Date
# 2008-08-15  0.400304  0.390132  0.445071     0.0 -0.054939    0.011256
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2008-08-15        15      8  2008                 0    4
# The last date of the training data is                  Open      High       Low    Volume  High-Low  Close-Open  \
# Date
# 2014-10-15  0.629108  0.627546  0.642293  0.054153 -0.014747    0.009032
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2014-10-15        15     10  2014                 0    2
# The start date of the training data is                 Open      High       Low    Volume  High-Low  Close-Open  \
# Date
# 2014-10-16  0.61222  0.627893  0.641268  0.131199 -0.013375    0.022224
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2014-10-16        16     10  2014                 0    3
# The last date of the training data is                  Open      High       Low    Volume  High-Low  Close-Open  \
# Date
# 2017-11-10  0.992789  0.991536  0.992578  0.059119 -0.001042    -0.00189
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2017-11-10        10     11  2017                 0    4
# Preprocessed data saved to C:\Users\rjdeo\OneDrive - University of North Carolina at Charlotte\Spring 2023\ICTS 6156\Project\Dataset\Output\preprocessed_stock\ETFs\offset_5_6\aaxj_5_6_preprocessed.pkl
# Selected dataset: C:\Users\rjdeo\OneDrive - University of North Carolina at Charlotte\Spring 2023\ICTS 6156\Project\Dataset\Data_Stockand ETP\Data\Etfs_1\acim.us.txt
# STOCK NAME: acim
#                 Open      High       Low     Close    Volume  High-Low  \
# Date
# 2012-03-06  0.090498  0.089982  0.091056  0.089982  0.001359 -0.001074
# 2012-03-07  0.094479  0.093941  0.095062  0.093941  0.000192 -0.001122
# 2012-03-08  0.115416  0.114758  0.116129  0.114758  0.000528 -0.001370
# 2012-03-12  0.113544  0.112897  0.114245  0.112897  0.003538 -0.001348
# 2012-03-13  0.166150  0.165203  0.132021  0.130463  0.000528  0.033182
#
#             Close-Open  Day_date  Month  Year  near_end_quarter  Day
# Date
# 2012-03-06   -0.000516         6      3  2012                 0    1
# 2012-03-07   -0.000539         7      3  2012                 0    2
# 2012-03-08   -0.000658         8      3  2012                 0    3
# 2012-03-12   -0.000647        12      3  2012                 0    0
# 2012-03-13   -0.035687        13      3  2012                 0    1
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1232 entries, 2012-03-06 to 2017-11-10
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Open              1232 non-null   float64
#  1   High              1232 non-null   float64
#  2   Low               1232 non-null   float64
#  3   Close             1232 non-null   float64
#  4   Volume            1232 non-null   float64
#  5   High-Low          1232 non-null   float64
#  6   Close-Open        1232 non-null   float64
#  7   Day_date          1232 non-null   int32
#  8   Month             1232 non-null   int32
#  9   Year              1232 non-null   int32
#  10  near_end_quarter  1232 non-null   int64
#  11  Day               1232 non-null   int64
# dtypes: float64(7), int32(3), int64(2)
# memory usage: 110.7 KB
# None
#               Open         High          Low        Close       Volume  \
# count  1232.000000  1232.000000  1232.000000  1232.000000  1232.000000
# mean      0.535038     0.539238     0.529980     0.531465     0.017966
# std       0.207600     0.207741     0.207997     0.206603     0.055298
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.437880     0.450080     0.426521     0.435561     0.002939
# 50%       0.557608     0.560342     0.551484     0.552371     0.006690
# 75%       0.642634     0.648751     0.635762     0.638984     0.014220
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#           High-Low   Close-Open     Day_date        Month         Year  \
# count  1232.000000  1232.000000  1232.000000  1232.000000  1232.000000
# mean      0.009258    -0.003573    15.728084     6.595779  2014.832792
# std       0.025182     0.014731     8.748768     3.371007     1.536862
# min      -0.011602    -0.109194     1.000000     1.000000  2012.000000
# 25%      -0.002332    -0.008353     8.000000     4.000000  2014.000000
# 50%       0.003033    -0.003001    16.000000     7.000000  2015.000000
# 75%       0.013532     0.000849    23.000000     9.000000  2016.000000
# max       0.441976     0.182659    31.000000    12.000000  2017.000000
#
#        near_end_quarter          Day
# count       1232.000000  1232.000000
# mean           0.077922     2.009740
# std            0.268158     1.406693
# min            0.000000     0.000000
# 25%            0.000000     1.000000
# 50%            0.000000     2.000000
# 75%            0.000000     3.000000
# max            1.000000     4.000000
# The start date of the training data is                  Open      High       Low    Volume  High-Low  Close-Open  \
# Date
# 2012-03-06  0.090498  0.089982  0.091056  0.001359 -0.001074   -0.000516
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2012-03-06         6      3  2012                 0    1
# The last date of the training data is                  Open      High       Low    Volume  High-Low  Close-Open  \
# Date
# 2016-03-29  0.510869  0.536614  0.514022  0.007052  0.022592    0.025745
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2016-03-29        29      3  2016                 1    1
# The start date of the training data is                  Open      High       Low    Volume  High-Low  Close-Open  \
# Date
# 2016-03-30  0.537765  0.543457  0.541084  0.001521  0.002373    0.005692
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2016-03-30        30      3  2016                 1    2
# The last date of the training data is                  Open      High       Low    Volume  High-Low  Close-Open  \
# Date
# 2017-11-10  0.974881  0.978501  0.980897  0.018611 -0.002396     0.00362
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2017-11-10        10     11  2017                 0    4
# Preprocessed data saved to C:\Users\rjdeo\OneDrive - University of North Carolina at Charlotte\Spring 2023\ICTS 6156\Project\Dataset\Output\preprocessed_stock\ETFs\offset_5_6\acim_5_6_preprocessed.pkl
# Selected dataset: C:\Users\rjdeo\OneDrive - University of North Carolina at Charlotte\Spring 2023\ICTS 6156\Project\Dataset\Data_Stockand ETP\Data\Etfs_1\actx.us.txt
# STOCK NAME: actx
#                 Open      High       Low     Close    Volume  High-Low  \
# Date
# 2015-04-30  0.799202  0.783534  0.784195  0.762715  0.482554 -0.000660
# 2015-05-01  0.803002  0.791365  0.793693  0.796555  0.107249 -0.002328
# 2015-05-04  0.830927  0.819076  0.817819  0.804661  0.210748  0.001257
# 2015-05-05  0.821619  0.799398  0.778685  0.760689  1.000000  0.020712
# 2015-05-06  0.780585  0.752008  0.754369  0.738804  0.123476 -0.002361
#
#             Close-Open  Day_date  Month  Year  near_end_quarter  Day
# Date
# 2015-04-30   -0.036487        30      4  2015                 0    3
# 2015-05-01   -0.006446         1      5  2015                 0    4
# 2015-05-04   -0.026266         4      5  2015                 0    0
# 2015-05-05   -0.060930         5      5  2015                 0    1
# 2015-05-06   -0.041781         6      5  2015                 0    2
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 272 entries, 2015-04-30 to 2017-10-04
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Open              272 non-null    float64
#  1   High              272 non-null    float64
#  2   Low               272 non-null    float64
#  3   Close             272 non-null    float64
#  4   Volume            272 non-null    float64
#  5   High-Low          272 non-null    float64
#  6   Close-Open        272 non-null    float64
#  7   Day_date          272 non-null    int32
#  8   Month             272 non-null    int32
#  9   Year              272 non-null    int32
#  10  near_end_quarter  272 non-null    int64
#  11  Day               272 non-null    int64
# dtypes: float64(7), int32(3), int64(2)
# memory usage: 24.4 KB
# None
#              Open        High         Low       Close      Volume    High-Low  \
# count  272.000000  272.000000  272.000000  272.000000  272.000000  272.000000
# mean     0.637340    0.606264    0.632235    0.606595    0.032053   -0.025971
# std      0.206353    0.214587    0.206756    0.216532    0.117503    0.031363
# min      0.000000    0.000000    0.000000    0.000000    0.000000   -0.069149
# 25%      0.466043    0.424448    0.462623    0.420213    0.002178   -0.040695
# 50%      0.698328    0.673293    0.691869    0.668886    0.006220   -0.028832
# 75%      0.792335    0.775753    0.789324    0.771864    0.017526   -0.017790
# max      1.000000    1.000000    1.000000    1.000000    1.000000    0.367068
#
#        Close-Open    Day_date       Month         Year  near_end_quarter  \
# count  272.000000  272.000000  272.000000   272.000000        272.000000
# mean    -0.030745   15.018382    6.617647  2015.944853          0.080882
# std      0.029609    8.983155    3.275896     0.824381          0.273157
# min     -0.122632    1.000000    1.000000  2015.000000          0.000000
# 25%     -0.044301    7.000000    5.000000  2015.000000          0.000000
# 50%     -0.030686   15.000000    6.000000  2016.000000          0.000000
# 75%     -0.019454   22.250000    9.000000  2017.000000          0.000000
# max      0.320567   31.000000   12.000000  2017.000000          1.000000
#
#               Day
# count  272.000000
# mean     1.992647
# std      1.414194
# min      0.000000
# 25%      1.000000
# 50%      2.000000
# 75%      3.000000
# max      4.000000
# The start date of the training data is                  Open      High       Low    Volume  High-Low  Close-Open  \
# Date
# 2015-04-30  0.799202  0.783534  0.784195  0.482554  -0.00066   -0.036487
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2015-04-30        30      4  2015                 0    3
# The last date of the training data is                  Open      High       Low    Volume  High-Low  Close-Open  \
# Date
# 2016-12-16  0.706117  0.673293  0.690919  0.003713 -0.017626    -0.03479
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2016-12-16        16     12  2016                 0    4
# The start date of the training data is                  Open      High       Low    Volume  High-Low  Close-Open  \
# Date
# 2016-12-22  0.709916  0.679317  0.700418  0.010601 -0.021101   -0.036563
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2016-12-22        22     12  2016                 0    3
# The last date of the training data is              Open  High  Low    Volume  High-Low  Close-Open  Day_date  Month  \
# Date
# 2017-10-04   1.0   1.0  1.0  0.028764       0.0         0.0         4     10
#
#             Year  near_end_quarter  Day
# Date
# 2017-10-04  2017                 0    2
# Preprocessed data saved to C:\Users\rjdeo\OneDrive - University of North Carolina at Charlotte\Spring 2023\ICTS 6156\Project\Dataset\Output\preprocessed_stock\ETFs\offset_5_6\actx_5_6_preprocessed.pkl
# Selected dataset: C:\Users\rjdeo\OneDrive - University of North Carolina at Charlotte\Spring 2023\ICTS 6156\Project\Dataset\Data_Stockand ETP\Data\Etfs_1\acwf.us.txt
# STOCK NAME: acwf
#                 Open      High       Low     Close    Volume  High-Low  \
# Date
# 2015-06-03  0.440281  0.424489  0.448077  0.443453  0.000410 -0.023588
# 2015-06-04  0.417418  0.396995  0.424904  0.416864  0.002045 -0.027909
# 2015-06-05  0.398160  0.385605  0.405385  0.405849  0.003272 -0.019780
# 2015-06-08  0.406413  0.385605  0.413750  0.405849  0.000203 -0.028145
# 2015-06-09  0.385447  0.367636  0.392500  0.388472  0.002045 -0.024864
#
#             Close-Open  Day_date  Month  Year  near_end_quarter  Day
# Date
# 2015-06-03    0.003172         3      6  2015                 0    2
# 2015-06-04   -0.000553         4      6  2015                 0    3
# 2015-06-05    0.007690         5      6  2015                 0    4
# 2015-06-08   -0.000564         8      6  2015                 0    0
# 2015-06-09    0.003025         9      6  2015                 0    1
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 403 entries, 2015-06-03 to 2017-11-10
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Open              403 non-null    float64
#  1   High              403 non-null    float64
#  2   Low               403 non-null    float64
#  3   Close             403 non-null    float64
#  4   Volume            403 non-null    float64
#  5   High-Low          403 non-null    float64
#  6   Close-Open        403 non-null    float64
#  7   Day_date          403 non-null    int32
#  8   Month             403 non-null    int32
#  9   Year              403 non-null    int32
#  10  near_end_quarter  403 non-null    int64
#  11  Day               403 non-null    int64
# dtypes: float64(7), int32(3), int64(2)
# memory usage: 36.2 KB
# None
#              Open        High         Low       Close      Volume    High-Low  \
# count  403.000000  403.000000  403.000000  403.000000  403.000000  403.000000
# mean     0.490423    0.477446    0.494376    0.489321    0.007745   -0.016930
# std      0.246974    0.255598    0.250562    0.247543    0.050264    0.015967
# min      0.000000    0.000000    0.000000    0.000000    0.000000   -0.035375
# 25%      0.296604    0.275334    0.300288    0.296363    0.000794   -0.027879
# 50%      0.427569    0.409466    0.431442    0.428924    0.002143   -0.020285
# 75%      0.705915    0.703947    0.714346    0.704112    0.006088   -0.011051
# max      1.000000    1.000000    1.000000    1.000000    1.000000    0.163150
#
#        Close-Open    Day_date       Month         Year  near_end_quarter  \
# count  403.000000  403.000000  403.000000   403.000000        403.000000
# mean    -0.001102   15.965261    6.746898  2016.248139          0.081886
# std      0.011285    8.836761    3.310688     0.799854          0.274532
# min     -0.054035    1.000000    1.000000  2015.000000          0.000000
# 25%     -0.003474    9.000000    4.000000  2016.000000          0.000000
# 50%     -0.000586   16.000000    7.000000  2016.000000          0.000000
# 75%      0.002213   23.000000   10.000000  2017.000000          0.000000
# max      0.045633   31.000000   12.000000  2017.000000          1.000000
#
#               Day
# count  403.000000
# mean     1.947891
# std      1.367630
# min      0.000000
# 25%      1.000000
# 50%      2.000000
# 75%      3.000000
# max      4.000000
# The start date of the training data is                  Open      High       Low   Volume  High-Low  Close-Open  \
# Date
# 2015-06-03  0.440281  0.424489  0.448077  0.00041 -0.023588    0.003172
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2015-06-03         3      6  2015                 0    2
# The last date of the training data is                  Open      High       Low    Volume  High-Low  Close-Open  \
# Date
# 2017-04-18  0.541125  0.525039  0.547596  0.000624 -0.022557   -0.003095
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2017-04-18        18      4  2017                 0    1
# The start date of the training data is                  Open      High       Low    Volume  High-Low  Close-Open  \
# Date
# 2017-04-24  0.591026  0.579733  0.600865  0.008617 -0.021132    0.001796
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2017-04-24        24      4  2017                 0    0
# The last date of the training data is                  Open      High       Low  Volume  High-Low  Close-Open  \
# Date
# 2017-11-10  0.980818  0.980951  0.995163  0.0017 -0.014213   -0.000787
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2017-11-10        10     11  2017                 0    4
# Preprocessed data saved to C:\Users\rjdeo\OneDrive - University of North Carolina at Charlotte\Spring 2023\ICTS 6156\Project\Dataset\Output\preprocessed_stock\ETFs\offset_5_6\acwf_5_6_preprocessed.pkl
# Selected dataset: C:\Users\rjdeo\OneDrive - University of North Carolina at Charlotte\Spring 2023\ICTS 6156\Project\Dataset\Data_Stockand ETP\Data\Etfs_1\acwi.us.txt
# STOCK NAME: acwi
#                 Open      High       Low     Close    Volume  High-Low  \
# Date
# 2008-03-28  0.458741  0.450997  0.460514  0.455935  0.000000 -0.009517
# 2008-03-31  0.457003  0.449243  0.446992  0.442413  0.000022  0.002251
# 2008-04-01  0.461379  0.460695  0.461594  0.465556  0.000043 -0.000899
# 2008-04-02  0.556404  0.549547  0.477076  0.475297  0.001175  0.072471
# 2008-04-03  0.625854  0.619629  0.475356  0.480338  0.003224  0.144273
#
#             Close-Open  Day_date  Month  Year  near_end_quarter  Day
# Date
# 2008-03-28   -0.002807        28      3  2008                 1    4
# 2008-03-31   -0.014590        31      3  2008                 1    0
# 2008-04-01    0.004177         1      4  2008                 0    1
# 2008-04-02   -0.081107         2      4  2008                 0    2
# 2008-04-03   -0.145517         3      4  2008                 0    3
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2425 entries, 2008-03-28 to 2017-11-10
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Open              2425 non-null   float64
#  1   High              2425 non-null   float64
#  2   Low               2425 non-null   float64
#  3   Close             2425 non-null   float64
#  4   Volume            2425 non-null   float64
#  5   High-Low          2425 non-null   float64
#  6   Close-Open        2425 non-null   float64
#  7   Day_date          2425 non-null   int32
#  8   Month             2425 non-null   int32
#  9   Year              2425 non-null   int32
#  10  near_end_quarter  2425 non-null   int64
#  11  Day               2425 non-null   int64
# dtypes: float64(7), int32(3), int64(2)
# memory usage: 217.9 KB
# None
#               Open         High          Low        Close       Volume  \
# count  2425.000000  2425.000000  2425.000000  2425.000000  2425.000000
# mean      0.516118     0.513523     0.512321     0.513114     0.104098
# std       0.214053     0.215053     0.215750     0.214597     0.106520
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.349890     0.347245     0.345475     0.347882     0.030245
# 50%       0.496583     0.493195     0.492959     0.492019     0.076734
# 75%       0.695564     0.694087     0.692711     0.692603     0.141087
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#           High-Low   Close-Open     Day_date        Month         Year  \
# count  2425.000000  2425.000000  2425.000000  2425.000000  2425.000000
# mean      0.001203    -0.003004    15.694845     6.593814  2012.545567
# std       0.008189     0.008393     8.761466     3.361284     2.793735
# min      -0.009517    -0.145517     1.000000     1.000000  2008.000000
# 25%      -0.002875    -0.006348     8.000000     4.000000  2010.000000
# 50%      -0.000637    -0.002277    16.000000     7.000000  2013.000000
# 75%       0.002689     0.001116    23.000000     9.000000  2015.000000
# max       0.144273     0.048101    31.000000    12.000000  2017.000000
#
#        near_end_quarter          Day
# count       2425.000000  2425.000000
# mean           0.075052     2.019381
# std            0.263529     1.399565
# min            0.000000     0.000000
# 25%            0.000000     1.000000
# 50%            0.000000     2.000000
# 75%            0.000000     3.000000
# max            1.000000     4.000000
# The start date of the training data is                  Open      High       Low  Volume  High-Low  Close-Open  \
# Date
# 2008-03-28  0.458741  0.450997  0.460514     0.0 -0.009517   -0.002807
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2008-03-28        28      3  2008                 1    4
# The last date of the training data is                Open      High       Low    Volume  High-Low  Close-Open  \
# Date
# 2014-08-28  0.7204  0.718442  0.721735  0.114502 -0.003294    0.000667
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2014-08-28        28      8  2014                 0    3
# The start date of the training data is                  Open      High       Low    Volume  High-Low  Close-Open  \
# Date
# 2014-08-29  0.724156  0.720317  0.722656  0.267228 -0.002339   -0.001029
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2014-08-29        29      8  2014                 0    4
# The last date of the training data is                  Open      High       Low    Volume  High-Low  Close-Open  \
# Date
# 2017-11-10  0.992807  0.991129  0.993099  0.053717  -0.00197   -0.002008
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2017-11-10        10     11  2017                 0    4
# Preprocessed data saved to C:\Users\rjdeo\OneDrive - University of North Carolina at Charlotte\Spring 2023\ICTS 6156\Project\Dataset\Output\preprocessed_stock\ETFs\offset_5_6\acwi_5_6_preprocessed.pkl
# Selected dataset: C:\Users\rjdeo\OneDrive - University of North Carolina at Charlotte\Spring 2023\ICTS 6156\Project\Dataset\Data_Stockand ETP\Data\Etfs_1\acwv.us.txt
# STOCK NAME: acwv
#                 Open      High       Low     Close    Volume  High-Low  \
# Date
# 2011-10-26  0.051825  0.053115  0.063974  0.063734  0.000124 -0.010859
# 2011-10-27  0.076269  0.075850  0.091628  0.091284  0.000000 -0.015778
# 2011-10-28  0.065286  0.068331  0.080828  0.083878  0.000186 -0.012497
# 2011-10-31  0.054149  0.053852  0.060407  0.060181  0.000042 -0.006555
# 2011-11-01  0.222421  0.221199  0.044709  0.044541  0.009515  0.176490
#
#             Close-Open  Day_date  Month  Year  near_end_quarter  Day
# Date
# 2011-10-26    0.011909        26     10  2011                 0    2
# 2011-10-27    0.015016        27     10  2011                 0    3
# 2011-10-28    0.018592        28     10  2011                 0    4
# 2011-10-31    0.006031        31     10  2011                 0    0
# 2011-11-01   -0.177880         1     11  2011                 0    1
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1491 entries, 2011-10-26 to 2017-11-10
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Open              1491 non-null   float64
#  1   High              1491 non-null   float64
#  2   Low               1491 non-null   float64
#  3   Close             1491 non-null   float64
#  4   Volume            1491 non-null   float64
#  5   High-Low          1491 non-null   float64
#  6   Close-Open        1491 non-null   float64
#  7   Day_date          1491 non-null   int32
#  8   Month             1491 non-null   int32
#  9   Year              1491 non-null   int32
#  10  near_end_quarter  1491 non-null   int64
#  11  Day               1491 non-null   int64
# dtypes: float64(7), int32(3), int64(2)
# memory usage: 134.0 KB
# None
#               Open         High          Low        Close       Volume  \
# count  1491.000000  1491.000000  1491.000000  1491.000000  1491.000000
# mean      0.497232     0.499231     0.499725     0.503368     0.027030
# std       0.256661     0.255590     0.252794     0.252284     0.047353
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.300490     0.304771     0.306395     0.310450     0.006222
# 50%       0.512631     0.515683     0.510260     0.517404     0.015785
# 75%       0.698003     0.700685     0.697950     0.700986     0.032286
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#           High-Low   Close-Open     Day_date        Month         Year  \
# count  1491.000000  1491.000000  1491.000000  1491.000000  1491.000000
# mean     -0.000494     0.006135    15.716298     6.603622  2014.397049
# std       0.010225     0.010214     8.789293     3.404768     1.733783
# min      -0.016616    -0.177880     1.000000     1.000000  2011.000000
# 25%      -0.004960     0.000260     8.000000     4.000000  2013.000000
# 50%      -0.001087     0.006689    16.000000     7.000000  2014.000000
# 75%       0.002373     0.012532    23.000000    10.000000  2016.000000
# max       0.221517     0.042459    31.000000    12.000000  2017.000000
#
#        near_end_quarter          Day
# count       1491.000000  1491.000000
# mean           0.073776     2.021462
# std            0.261494     1.398300
# min            0.000000     0.000000
# 25%            0.000000     1.000000
# 50%            0.000000     2.000000
# 75%            0.000000     3.000000
# max            1.000000     4.000000
# The start date of the training data is                  Open      High       Low    Volume  High-Low  Close-Open  \
# Date
# 2011-10-26  0.051825  0.053115  0.063974  0.000124 -0.010859    0.011909
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2011-10-26        26     10  2011                 0    2
# The last date of the training data is                  Open      High       Low    Volume  High-Low  Close-Open  \
# Date
# 2015-11-20  0.598376  0.600424  0.600759  0.015027 -0.000335    0.002731
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2015-11-20        20     11  2015                 0    4
# The start date of the training data is                  Open      High       Low    Volume  High-Low  Close-Open  \
# Date
# 2015-11-23  0.593242  0.596817  0.596187  0.022686  0.000629    0.004762
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2015-11-23        23     11  2015                 0    0
# The last date of the training data is                  Open      High       Low    Volume  High-Low  Close-Open  \
# Date
# 2017-11-10  0.993359  0.992222  0.991736  0.034062  0.000486   -0.002367
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2017-11-10        10     11  2017                 0    4
# Preprocessed data saved to C:\Users\rjdeo\OneDrive - University of North Carolina at Charlotte\Spring 2023\ICTS 6156\Project\Dataset\Output\preprocessed_stock\ETFs\offset_5_6\acwv_5_6_preprocessed.pkl
# Selected dataset: C:\Users\rjdeo\OneDrive - University of North Carolina at Charlotte\Spring 2023\ICTS 6156\Project\Dataset\Data_Stockand ETP\Data\Etfs_1\acwx.us.txt
# STOCK NAME: acwx
#                 Open      High       Low     Close    Volume  High-Low  \
# Date
# 2008-03-31  0.639483  0.607367  0.769437  0.764380  0.000032 -0.162070
# 2008-04-01  0.973400  0.930368  0.786266  0.793562  0.000161  0.144103
# 2008-04-02  0.674923  0.645533  0.811913  0.807182  0.000305 -0.166380
# 2008-04-03  0.680798  0.652806  0.818954  0.819670  0.000266 -0.166148
# 2008-04-04  0.804312  0.766808  0.823056  0.823229  0.000254 -0.056248
#
#             Close-Open  Day_date  Month  Year  near_end_quarter  Day
# Date
# 2008-03-31    0.124898        31      3  2008                 1    0
# 2008-04-01   -0.179838         1      4  2008                 0    1
# 2008-04-02    0.132260         2      4  2008                 0    2
# 2008-04-03    0.138872         3      4  2008                 0    3
# 2008-04-04    0.018917         4      4  2008                 0    4
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2424 entries, 2008-03-31 to 2017-11-10
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Open              2424 non-null   float64
#  1   High              2424 non-null   float64
#  2   Low               2424 non-null   float64
#  3   Close             2424 non-null   float64
#  4   Volume            2424 non-null   float64
#  5   High-Low          2424 non-null   float64
#  6   Close-Open        2424 non-null   float64
#  7   Day_date          2424 non-null   int32
#  8   Month             2424 non-null   int32
#  9   Year              2424 non-null   int32
#  10  near_end_quarter  2424 non-null   int64
#  11  Day               2424 non-null   int64
# dtypes: float64(7), int32(3), int64(2)
# memory usage: 217.8 KB
# None
#               Open         High          Low        Close       Volume  \
# count  2424.000000  2424.000000  2424.000000  2424.000000  2424.000000
# mean      0.505689     0.482856     0.601466     0.603256     0.057420
# std       0.153175     0.146919     0.185516     0.183470     0.081230
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.417424     0.396354     0.495341     0.496199     0.013958
# 50%       0.521251     0.496220     0.622016     0.622080     0.031570
# 75%       0.614075     0.586277     0.732049     0.733719     0.068782
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#           High-Low   Close-Open     Day_date        Month         Year  \
# count  2424.000000  2424.000000  2424.000000  2424.000000  2424.000000
# mean     -0.118610     0.097567    15.689769     6.595297  2012.547442
# std       0.041547     0.033505     8.759706     3.361184     2.792785
# min      -0.203404    -0.179838     1.000000     1.000000  2008.000000
# 25%      -0.146844     0.079599     8.000000     4.000000  2010.000000
# 50%      -0.123625     0.101282    16.000000     7.000000  2013.000000
# 75%      -0.097905     0.120365    23.000000     9.000000  2015.000000
# max       0.181563     0.171109    31.000000    12.000000  2017.000000
#
#        near_end_quarter          Day
# count       2424.000000  2424.000000
# mean           0.074670     2.018564
# std            0.262912     1.399275
# min            0.000000     0.000000
# 25%            0.000000     1.000000
# 50%            0.000000     2.000000
# 75%            0.000000     3.000000
# max            1.000000     4.000000
# The start date of the training data is                  Open      High       Low    Volume  High-Low  Close-Open  \
# Date
# 2008-03-31  0.639483  0.607367  0.769437  0.000032  -0.16207    0.124898
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2008-03-31        31      3  2008                 1    0
# The last date of the training data is                  Open     High       Low    Volume  High-Low  Close-Open  \
# Date
# 2014-08-28  0.689638  0.65802  0.828031  0.030948  -0.17001    0.137053
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2014-08-28        28      8  2014                 0    3
# The start date of the training data is                 Open      High     Low    Volume  High-Low  Close-Open  \
# Date
# 2014-08-29  0.69085  0.658281  0.8269  0.031399 -0.168619     0.13584
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2014-08-29        29      8  2014                 0    4
# The last date of the training data is                  Open      High       Low    Volume  High-Low  Close-Open  \
# Date
# 2017-11-10  0.825118  0.787455  0.987726  0.021936  -0.20027    0.160162
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2017-11-10        10     11  2017                 0    4
# Preprocessed data saved to C:\Users\rjdeo\OneDrive - University of North Carolina at Charlotte\Spring 2023\ICTS 6156\Project\Dataset\Output\preprocessed_stock\ETFs\offset_5_6\acwx_5_6_preprocessed.pkl
# Selected dataset: C:\Users\rjdeo\OneDrive - University of North Carolina at Charlotte\Spring 2023\ICTS 6156\Project\Dataset\Data_Stockand ETP\Data\Etfs_1\adra.us.txt
# STOCK NAME: adra
#                 Open      High       Low     Close    Volume  High-Low  \
# Date
# 2005-02-25  0.309482  0.303975  0.314557  0.312777  0.088628 -0.010582
# 2005-02-28  0.434043  0.425002  0.323576  0.317866  0.055599  0.101427
# 2005-03-01  0.316324  0.308709  0.324871  0.318659  0.037151 -0.016162
# 2005-03-02  0.345566  0.336505  0.320939  0.315858  0.031815  0.015566
# 2005-03-03  0.316652  0.308709  0.323576  0.316278  0.033202 -0.014867
#
#             Close-Open  Day_date  Month  Year  near_end_quarter  Day
# Date
# 2005-02-25    0.003295        25      2  2005                 0    4
# 2005-02-28   -0.116177        28      2  2005                 0    0
# 2005-03-01    0.002336         1      3  2005                 0    1
# 2005-03-02   -0.029708         2      3  2005                 0    2
# 2005-03-03   -0.000373         3      3  2005                 0    3
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2986 entries, 2005-02-25 to 2017-11-10
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Open              2986 non-null   float64
#  1   High              2986 non-null   float64
#  2   Low               2986 non-null   float64
#  3   Close             2986 non-null   float64
#  4   Volume            2986 non-null   float64
#  5   High-Low          2986 non-null   float64
#  6   Close-Open        2986 non-null   float64
#  7   Day_date          2986 non-null   int32
#  8   Month             2986 non-null   int32
#  9   Year              2986 non-null   int32
#  10  near_end_quarter  2986 non-null   int64
#  11  Day               2986 non-null   int64
# dtypes: float64(7), int32(3), int64(2)
# memory usage: 268.3 KB
# None
#               Open         High          Low        Close       Volume  \
# count  2986.000000  2986.000000  2986.000000  2986.000000  2986.000000
# mean      0.523001     0.520139     0.521880     0.523034     0.037665
# std       0.180135     0.179513     0.179140     0.180045     0.071235
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.383572     0.379933     0.386709     0.384996     0.003102
# 50%       0.531775     0.527866     0.530228     0.531721     0.011973
# 75%       0.659055     0.655245     0.658344     0.658548     0.045452
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#           High-Low   Close-Open     Day_date        Month         Year  \
# count  2986.000000  2986.000000  2986.000000  2986.000000  2986.000000
# mean     -0.001741     0.000033    15.711319     6.539518  2010.720027
# std       0.016787     0.014503     8.763889     3.386931     3.613669
# min      -0.018413    -0.205678     1.000000     1.000000  2005.000000
# 25%      -0.010582    -0.004726     8.000000     4.000000  2008.000000
# 50%      -0.005602     0.000187    16.000000     7.000000  2011.000000
# 75%       0.001256     0.005538    23.000000     9.000000  2014.000000
# max       0.300120     0.146713    31.000000    12.000000  2017.000000
#
#        near_end_quarter          Day
# count       2986.000000  2986.000000
# mean           0.076691     2.026457
# std            0.266145     1.399319
# min            0.000000     0.000000
# 25%            0.000000     1.000000
# 50%            0.000000     2.000000
# 75%            0.000000     3.000000
# max            1.000000     4.000000
# The start date of the training data is                  Open      High       Low    Volume  High-Low  Close-Open  \
# Date
# 2005-02-25  0.309482  0.303975  0.314557  0.088628 -0.010582    0.003295
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2005-02-25        25      2  2005                 0    4
# The last date of the training data is                  Open      High       Low    Volume  High-Low  Close-Open  \
# Date
# 2013-03-05  0.530018  0.523062  0.536148  0.001094 -0.013086    0.001703
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2013-03-05         5      3  2013                 0    1
# The start date of the training data is                 Open      High       Low    Volume  High-Low  Close-Open  \
# Date
# 2013-03-06  0.53686  0.529437  0.541652  0.001871 -0.012215   -0.000424
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2013-03-06         6      3  2013                 0    2
# The last date of the training data is                  Open      High       Low  Volume  High-Low  Close-Open  \
# Date
# 2017-11-10  0.991101  0.982188  0.991217     0.0 -0.009029   -0.001371
#
#             Day_date  Month  Year  near_end_quarter  Day
# Date
# 2017-11-10        10     11  2017                 0    4
# Preprocessed data saved to C:\Users\rjdeo\OneDrive - University of North Carolina at Charlotte\Spring 2023\ICTS 6156\Project\Dataset\Output\preprocessed_stock\ETFs\offset_5_6\adra_5_6_preprocessed.pkl
